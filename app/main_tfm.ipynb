# %% [markdown]
# # cia-data-loader

# %% [markdown]
# ## Objetivos del sistema

# %% [markdown]
# ✅ Leer cualquier fichero presente en el directorio file.
#
# ✅ Generar los dataframe dinamicamente
#
# ❌ Identificar las claves primarias de cada dataframe
#
# ❌ Identificar las claves forneas de cada dataframe
#
# ❌ Crear el esquema en Progress correspondiente a los ficheros incorporados.
#
# ❌ Cargar los datos en esquema de base de datos

# %% [markdown]
# ## 🛠️ Instalación

# %% [markdown]
# En este epigrafe realizaremos todos los pasos necesarios para tener el entorno listo para la ejecución

# %% [markdown]
# ###🔨.Requisitos Previos

# %% [markdown]
# ### get_environment_info
#
# Esta función detecta si el entorno donde se ejecuta el código es:
#
# 🐳 Un contenedor Docker
#
# 💻 Una máquina virtual (VM)
#
# 🖥️ Un sistema físico (bare-metal)
#
# **Dado que es necesario saber que tipo de entorno al principio es mas limpio crear esta función cargar las librerias**

# %%
def get_environment_info():
    import os
    import platform
    import subprocess

    def is_docker():
        try:
            if os.path.exists("/.dockerenv"):
                return True
            with open("/proc/1/cgroup", "r") as f:
                if "docker" in f.read() or "containerd" in f.read():
                    return True
        except Exception:
            pass
        return False

    def is_virtual_machine():
        system = platform.system()

        try:
            if system == "Linux":
                try:
                    output = subprocess.check_output(["systemd-detect-virt"], stderr=subprocess.DEVNULL).decode().strip()
                    if output and output != "none":
                        return True, output
                except Exception:
                    pass

                try:
                    with open("/proc/cpuinfo", "r") as f:
                        if "hypervisor" in f.read().lower():
                            return True, "Desconocido (hypervisor detectado)"
                except Exception:
                    pass

                try:
                    output = subprocess.check_output(["dmidecode", "-s", "system-product-name"], stderr=subprocess.DEVNULL).decode().strip().lower()
                    for vm in ["virtualbox", "kvm", "vmware", "microsoft"]:
                        if vm in output:
                            return True, vm.capitalize()
                except Exception:
                    pass

            elif system == "Windows":
                try:
                    ps_script = "Get-CimInstance -ClassName Win32_ComputerSystem | Select-Object -ExpandProperty Model"
                    output = subprocess.check_output(["powershell", "-Command", ps_script], stderr=subprocess.DEVNULL).decode().strip().lower()
                    for vm in ["virtualbox", "kvm", "vmware", "hyper-v", "virtual"]:
                        if vm in output:
                            return True, vm.capitalize()
                except Exception:
                    pass

        except Exception:
            pass

        return False, None

    docker = is_docker()
    vm, vm_type = is_virtual_machine()

    if docker:
        entorno = "docker"
        is_virtual = True
    elif vm:
        entorno = "virtual"
        is_virtual = True
    else:
        entorno = "real"
        is_virtual = False

    return {
        "docker": docker,
        "virtual_machine": vm,
        "hypervisor": vm_type if vm else False,
        "entorno": entorno,
        "is_virtual" : is_virtual
    }

# Ejemplo de uso
env_info = get_environment_info()
print(env_info)

if env_info["entorno"] == "Docker":
    print("🐳 Ejecutándose dentro de un contenedor Docker")
elif env_info["entorno"] == "virtual":
    print(f"💻 Ejecutándose en máquina virtual ({env_info['hypervisor']})")
else:
    print("🖥️ Ejecutándose en máquina física")
# Out:
# {'docker': False, 'virtual_machine': False, 'hypervisor': False, 'entorno': 'real', 'is_virtual': False}
# 🖥️ Ejecutándose en máquina física

# %% [markdown]
# Es necesario saber si el código esta corriendo en la maquina virtual o en local como paso previo ya que el ENV se ejecuta por parte de la máquina virtual en el arranque

# %%
if env_info.get("is_virtual") is False:
    # !pip install -r cia-data-loader_requirements.txt
# Out:
# Se esta ejecutando en una máquina virtual: is_virtual_machine
# Collecting nbimporter (from -r cia-data-loader_requirements.txt (line 1))
#   Using cached nbimporter-0.3.4-py3-none-any.whl.metadata (252 bytes)
# Collecting pandas==2.2.3 (from -r cia-data-loader_requirements.txt (line 2))
#   Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting networkx==3.4.2 (from -r cia-data-loader_requirements.txt (line 3))
#   Using cached networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting matplotlib==3.10.1 (from -r cia-data-loader_requirements.txt (line 4))
#   Using cached matplotlib-3.10.1-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: geocoder in c:\users\mx0046001dc5030\anaconda3\lib\site-packages (from -r cia-data-loader_requirements.txt (line 5)) (1.38.1)
# Requirement already satisfied: python-dotenv in c:\users\mx0046001dc5030\anaconda3\lib\site-packages (from -r cia-data-loader_requirements.txt (line 6)) (0.21.0)
# Requirement already satisfied: jupytext in c:\users\mx0046001dc5030\anaconda3\lib\site-packages (from -r cia-data-loader_requirements.txt (line 7)) (1.17.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\mx0046001dc5030\anaconda3\lib\site-packages (from pandas==2.2.3->-r cia-data-loader_requirements.txt (line 2)) (1.26.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\mx0046001dc5030\anaconda3\lib\site-packages (from pandas==2.2.3->-r cia-data-loader_requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mx0046001dc5030\anaconda3\lib\site-packages (from pandas==2.2.3->-r cia-data-loader_requirements.txt (line 2)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\mx0046001dc5030\anaconda3\lib\site-packages (from pandas==2.2.3->-r cia-data-loader_requirements.txt (line 2)) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\mx0046001dc5030\anaconda3\lib\site-packages (from matplotlib==3.10.1->-r cia-data-loader_requirements.txt (line 4)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\mx0046001dc5030\anaconda3\lib\site-packages (from matplotlib==3.10.1->-r cia-data-loader_requirements.txt (line 4)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mx0046001dc5030\anaconda3\lib\site-packages (from matplotlib==3.10.1->-r cia-data-loader_requirements.txt (line 4)) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\mx0046001dc5030\anaconda3\lib\site-packages (from matplotlib==3.10.1->-r cia-data-loader_requirements.txt (line 4)) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\mx0046001dc5030\anaconda3\lib\site-packages (from matplotlib==3.10.1->-r cia-data-loader_requirements.txt (line 4)) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\mx0046001dc5030\anaconda3\lib\site-packages (from matplotlib==3.10.1->-r cia-data-loader_requirements.txt (line 4)) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\mx0046001dc5030\anaconda3\lib\site-packages (from matplotlib==3.10.1->-r cia-data-loader_requirements.txt (line 4)) (3.1.2)
# Requirement already satisfied: click in c:\users\mx0046001dc5030\anaconda3\lib\site-packages (from geocoder->-r cia-data-loader_requirements.txt (line 5)) (8.1.7)
# Requirement already satisfied: future in c:\users\mx0046001dc5030\anaconda3\lib\site-packages (from geocoder->-r cia-data-loader_requirements.txt (line 5)) (1.0.0)
# Requirement already satisfied: ratelim in c:\users\mx0046001dc5030\anaconda3\lib\site-packages (from geocoder->-r cia-data-loader_requirements.txt (line 5)) (0.1.6)
# Requirement already satisfied: requests in c:\users\mx0046001dc5030\anaconda3\lib\site-packages (from geocoder->-r cia-data-loader_requirements.txt (line 5)) (2.32.3)
# Requirement already satisfied: six in c:\users\mx0046001dc5030\anaconda3\lib\site-packages (from geocoder->-r cia-data-loader_requirements.txt (line 5)) (1.16.0)
# Requirement already satisfied: markdown-it-py>=1.0 in c:\users\mx0046001dc5030\anaconda3\lib\site-packages (from jupytext->-r cia-data-loader_requirements.txt (line 7)) (2.2.0)
# Requirement already satisfied: mdit-py-plugins in c:\users\mx0046001dc5030\anaconda3\lib\site-packages (from jupytext->-r cia-data-loader_requirements.txt (line 7)) (0.3.0)
# Requirement already satisfied: nbformat in c:\users\mx0046001dc5030\anaconda3\lib\site-packages (from jupytext->-r cia-data-loader_requirements.txt (line 7)) (5.10.4)
# Requirement already satisfied: pyyaml in c:\users\mx0046001dc5030\anaconda3\lib\site-packages (from jupytext->-r cia-data-loader_requirements.txt (line 7)) (6.0.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\mx0046001dc5030\anaconda3\lib\site-packages (from markdown-it-py>=1.0->jupytext->-r cia-data-loader_requirements.txt (line 7)) (0.1.0)
# Requirement already satisfied: colorama in c:\users\mx0046001dc5030\anaconda3\lib\site-packages (from click->geocoder->-r cia-data-loader_requirements.txt (line 5)) (0.4.6)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\mx0046001dc5030\anaconda3\lib\site-packages (from nbformat->jupytext->-r cia-data-loader_requirements.txt (line 7)) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\mx0046001dc5030\anaconda3\lib\site-packages (from nbformat->jupytext->-r cia-data-loader_requirements.txt (line 7)) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\mx0046001dc5030\anaconda3\lib\site-packages (from nbformat->jupytext->-r cia-data-loader_requirements.txt (line 7)) (5.7.2)
# Requirement already satisfied: traitlets>=5.1 in c:\users\mx0046001dc5030\anaconda3\lib\site-packages (from nbformat->jupytext->-r cia-data-loader_requirements.txt (line 7)) (5.14.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\mx0046001dc5030\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->jupytext->-r cia-data-loader_requirements.txt (line 7)) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\mx0046001dc5030\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->jupytext->-r cia-data-loader_requirements.txt (line 7)) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\mx0046001dc5030\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->jupytext->-r cia-data-loader_requirements.txt (line 7)) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\mx0046001dc5030\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->jupytext->-r cia-data-loader_requirements.txt (line 7)) (0.10.6)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\mx0046001dc5030\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat->jupytext->-r cia-data-loader_requirements.txt (line 7)) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\mx0046001dc5030\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat->jupytext->-r cia-data-loader_requirements.txt (line 7)) (305.1)
# Requirement already satisfied: decorator in c:\users\mx0046001dc5030\anaconda3\lib\site-packages (from ratelim->geocoder->-r cia-data-loader_requirements.txt (line 5)) (5.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mx0046001dc5030\anaconda3\lib\site-packages (from requests->geocoder->-r cia-data-loader_requirements.txt (line 5)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mx0046001dc5030\anaconda3\lib\site-packages (from requests->geocoder->-r cia-data-loader_requirements.txt (line 5)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mx0046001dc5030\anaconda3\lib\site-packages (from requests->geocoder->-r cia-data-loader_requirements.txt (line 5)) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mx0046001dc5030\anaconda3\lib\site-packages (from requests->geocoder->-r cia-data-loader_requirements.txt (line 5)) (2025.1.31)
# Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl (11.5 MB)
# Using cached networkx-3.4.2-py3-none-any.whl (1.7 MB)
# Using cached matplotlib-3.10.1-cp312-cp312-win_amd64.whl (8.1 MB)
# Using cached nbimporter-0.3.4-py3-none-any.whl (4.9 kB)
# Installing collected packages: nbimporter, networkx, pandas, matplotlib
#
#   Attempting uninstall: networkx
#
#     Found existing installation: networkx 3.3
#
#     Uninstalling networkx-3.3:
#
#       Successfully uninstalled networkx-3.3
#
#    ---------- ----------------------------- 1/4 [networkx]
#    ---------- ----------------------------- 1/4 [networkx]
#    ---------- ----------------------------- 1/4 [networkx]
#    ---------- ----------------------------- 1/4 [networkx]
#    ---------- ----------------------------- 1/4 [networkx]
#    ---------- ----------------------------- 1/4 [networkx]
#    ---------- ----------------------------- 1/4 [networkx]
#    ---------- ----------------------------- 1/4 [networkx]
#    ---------- ----------------------------- 1/4 [networkx]
#    ---------- ----------------------------- 1/4 [networkx]
#    ---------- ----------------------------- 1/4 [networkx]
#    ---------- ----------------------------- 1/4 [networkx]
#    ---------- ----------------------------- 1/4 [networkx]
#   Attempting uninstall: pandas
#    ---------- ----------------------------- 1/4 [networkx]
#     Found existing installation: pandas 2.2.2
#    ---------- ----------------------------- 1/4 [networkx]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#     Uninstalling pandas-2.2.2:
#    -------------------- ------------------- 2/4 [pandas]
#       Successfully uninstalled pandas-2.2.2
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#    -------------------- ------------------- 2/4 [pandas]
#   Attempting uninstall: matplotlib
#    -------------------- ------------------- 2/4 [pandas]
#     Found existing installation: matplotlib 3.9.2
#    -------------------- ------------------- 2/4 [pandas]
#     Uninstalling matplotlib-3.9.2:
#    -------------------- ------------------- 2/4 [pandas]
#    ------------------------------ --------- 3/4 [matplotlib]
#    ------------------------------ --------- 3/4 [matplotlib]
#    ------------------------------ --------- 3/4 [matplotlib]
#    ------------------------------ --------- 3/4 [matplotlib]
#    ------------------------------ --------- 3/4 [matplotlib]
#    ------------------------------ --------- 3/4 [matplotlib]
#    ------------------------------ --------- 3/4 [matplotlib]
#    ------------------------------ --------- 3/4 [matplotlib]
#    ------------------------------ --------- 3/4 [matplotlib]
#    ------------------------------ --------- 3/4 [matplotlib]
#    ------------------------------ --------- 3/4 [matplotlib]
#       Successfully uninstalled matplotlib-3.9.2
#    ------------------------------ --------- 3/4 [matplotlib]
#    ------------------------------ --------- 3/4 [matplotlib]
#    ------------------------------ --------- 3/4 [matplotlib]
#    ------------------------------ --------- 3/4 [matplotlib]
#    ------------------------------ --------- 3/4 [matplotlib]
#    ------------------------------ --------- 3/4 [matplotlib]
#    ------------------------------ --------- 3/4 [matplotlib]
#    ------------------------------ --------- 3/4 [matplotlib]
#    ------------------------------ --------- 3/4 [matplotlib]
#    ------------------------------ --------- 3/4 [matplotlib]
#    ------------------------------ --------- 3/4 [matplotlib]
#    ------------------------------ --------- 3/4 [matplotlib]
#    ------------------------------ --------- 3/4 [matplotlib]
#    ------------------------------ --------- 3/4 [matplotlib]
#    ------------------------------ --------- 3/4 [matplotlib]
#    ------------------------------ --------- 3/4 [matplotlib]
#    ------------------------------ --------- 3/4 [matplotlib]
#    ------------------------------ --------- 3/4 [matplotlib]
#    ------------------------------ --------- 3/4 [matplotlib]
#    ------------------------------ --------- 3/4 [matplotlib]
#    ------------------------------ --------- 3/4 [matplotlib]
#    ------------------------------ --------- 3/4 [matplotlib]
#    ------------------------------ --------- 3/4 [matplotlib]
#    ------------------------------ --------- 3/4 [matplotlib]
#    ------------------------------ --------- 3/4 [matplotlib]
#    ------------------------------ --------- 3/4 [matplotlib]
#    ------------------------------ --------- 3/4 [matplotlib]
#    ------------------------------ --------- 3/4 [matplotlib]
#    ------------------------------ --------- 3/4 [matplotlib]
#    ------------------------------ --------- 3/4 [matplotlib]
#    ------------------------------ --------- 3/4 [matplotlib]
#    ------------------------------ --------- 3/4 [matplotlib]
#    ------------------------------ --------- 3/4 [matplotlib]
#    ---------------------------------------- 4/4 [matplotlib]
#
# Successfully installed matplotlib-3.10.1 nbimporter-0.3.4 networkx-3.4.2 pandas-2.2.3
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\MX0046001DC5030\anaconda3\Lib\site-packages\~andas'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\MX0046001DC5030\anaconda3\Lib\site-packages\~atplotlib'.
#   You can safely remove it manually.

# %% [markdown]
# ### ⛏️ Cadenas previas

# %%
# Al importar el codido py como notebook se genera esta linea que solo es necesario si se llama desde la máquina virtual
if env_info.get("is_virtual") is True:
    # %matplotlib inline
    # !/usr/bin/env python
    # coding: utf-8

# %% [markdown]
# ### 🔧Carga de librerias en el entorno

# %%
# Variables propias desarolladas por el equipo que ayuda a la construcción del TFM
import library_tfm_v0
# Carga de todas las funciones generadas
from library_tfm_v0 import *

# Permite cargar configuraciones sensibles (como claves API, contraseñas, nombres de usuario, URLs) desde un archivo .env, sin tener que codificarlas directamente en tu script.
from dotenv import load_dotenv


# Carga de CSV
import pandas as pd


# Para generar el gráfico de dependecias
import networkx as nx
import matplotlib.pyplot as plt

# Calculo de localizaciones
import geocoder

# Permite cargar configuraciones sensibles (como claves API, contraseñas, nombres de usuario, URLs) desde un archivo .env, sin tener que codificarlas directamente en tu script.
from dotenv import dotenv_values

# %% [markdown]
# ### 🔩 Carga de variables externas prefijadas

# %%
# Cargar las variables del archivo .env en un diccionario al cargarlo al entorno para 

if (env_info.get("is_virtual") is True):
    env_vars = dotenv_values(".env")
else:
    env_vars = dotenv_values("cia-data-loader.env")
    
# Asignar cada variable como una variable Python, pero con nombre en minúsculas
# De esta forma no tengo que cargarlas manualmente 
for key, value in env_vars.items():
    globals()[key.lower()] = value 
    print(f'{key.lower()}={value}')
# Out:
# postgres_user=admin
# postgres_password=secretpassword
# postgres_db=mydb
# postgres_host=tfm_ai_postgres_container
# python_file=files

# %% [markdown]
# ### 🔩Importación de librerias

# %% [markdown]
# ## 💙 Main

# %% [markdown]
# ### Inicialización de variables
#
# En este punto daremos los valores a las variables

# %%
if env_info.get("is_virtual") is False:
    clean_file(r'C:\Users\MX0046001DC5030\files', extensions=['.txt'])   
    dataframes= load_files_in_dataframes(r'C:\Users\MX0046001DC5030\files', sep=',', extensions=['.txt'])
else:
    clean_file(python_file,extensions=['.txt', '.csv'])   
    dataframes, list_id =load_files_in_dataframes(python_file, sep=',', extensions=['.txt', '.csv'])




if dataframes:
	for file_name, df in dataframes.items():
		print(f"\nInformación del DataFrame '{f'df_{file_name}'}':") # Imprime el nombre del DataFrame

		# print(f'Columnas :{globals()[f"df_{file_name}"].columns.tolist()}') #Imprime el nombre de cada columna 


		# print(f'CATA DEL DATAFRAME \n{globals()[f"df_{file_name}"].head(explore)}') #Imprime  un head de la tabla


	# ## Identificar dependencias entre los Df



tempGlobal = globals() ## Para evitar que intervengan las variables de esta celda
relactions = {}  # Define el diccionario relaciones aquí
relactions_M4 = {}
relactions_NO_M4 = {}

# Crear un grafo dirigido
G = nx.DiGraph()
G_NO_M4 = nx.DiGraph()
G_M4 = nx.DiGraph()
###PARA las tablas M4 y No M4 diferencias por la raiz

dependency_dataframes(globals())
tree_dataframes(globals())


# ## Pasos
# ### Cargar los datos 
# ### Función para identicar la boca de metro más cercana dada la localización del que pregunta 
# ### Función para identificar la geolocalización de la persona ✅ 
# 
# 



location_gps();
# Out:
# Procesando archivo: agency.txt
# df_agency lista: ['agency_id']
# Procesando archivo: calendar.txt
# df_calendar lista: ['service_id', 'agency_id']
# Procesando archivo: calendar_dates.txt
# df_calendar_dates lista: ['service_id', 'agency_id']
# Procesando archivo: fare_attributes.txt
# df_fare_attributes lista: ['fare_id', 'service_id', 'agency_id']
# Procesando archivo: fare_rules.txt
# df_fare_rules lista: ['contains_id', 'route_id', 'agency_id', 'service_id', 'origin_id', 'fare_id', 'destination_id']
# Procesando archivo: feed_info.txt
# df_feed_info lista: ['contains_id', 'route_id', 'agency_id', 'origin_id', 'fare_id', 'service_id', 'destination_id']
# Procesando archivo: frequencies.txt
# df_frequencies lista: ['contains_id', 'route_id', 'agency_id', 'service_id', 'origin_id', 'fare_id', 'destination_id', 'trip_id']
# Procesando archivo: routes.txt
# df_routes lista: ['contains_id', 'route_id', 'agency_id', 'origin_id', 'fare_id', 'service_id', 'destination_id', 'trip_id']
# Procesando archivo: shapes.txt
# df_shapes lista: ['contains_id', 'route_id', 'agency_id', 'service_id', 'origin_id', 'fare_id', 'destination_id', 'trip_id', 'shape_id']
# Procesando archivo: stops.txt
# df_stops lista: ['contains_id', 'route_id', 'stop_id', 'zone_id', 'agency_id', 'origin_id', 'fare_id', 'service_id', 'destination_id', 'trip_id', 'shape_id']
# Procesando archivo: stop_times.txt
# df_stop_times lista: ['contains_id', 'route_id', 'stop_id', 'zone_id', 'agency_id', 'service_id', 'origin_id', 'fare_id', 'destination_id', 'trip_id', 'shape_id']
# Procesando archivo: trips.txt
# df_trips lista: ['direction_id', 'contains_id', 'route_id', 'stop_id', 'zone_id', 'agency_id', 'origin_id', 'fare_id', 'service_id', 'destination_id', 'trip_id', 'shape_id', 'block_id']
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 12
#       6     dataframes, list_id =load_files_in_dataframes(python_file, sep=',', extensions=['.txt', '.csv'])
#      11 if dataframes:
# ---> 12 	for file_name, df in dataframes.items():
#      13 		print(f"\nInformación del DataFrame '{f'df_{file_name}'}':") # Imprime el nombre del DataFrame
#      15 		# print(f'Columnas :{globals()[f"df_{file_name}"].columns.tolist()}') #Imprime el nombre de cada columna
#      16
#      17
#    (...)
#      20
#      21 	# ## Identificar dependencias entre los Df
#
# AttributeError: 'tuple' object has no attribute 'items'
